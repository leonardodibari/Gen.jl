# %%
## Include packages

using DelimitedFiles
using DCAUtils
using Plots
using KitMSA
using FastaIO
using Statistics
using StatsBase
using LinearAlgebra


include("../src/read_write.jl")
include("../src/energy.jl")
include("../src/msa_tools.jl")
include("../src/extra_tools.jl")
;

# %%
PATH_PAR_dbd = "../data/model_parameters/Parameters_conv_Thr-PCD40.dat"
htmp, Jtmp = KitMSA.read_par_BM(PATH_PAR_dbd)
h = KitMSA.set_max_field_to_0(htmp)
J = KitMSA.symmetrize_J(Jtmp)
maximum(J)
;

# %%
function compare_seq(a::Array{Int8,1}, b::Array{Int8,1})
    if a == b
        return 0
    else
        return findall(a .!= b)[1]
    end
end

function find_positions(msa)
    
    return [compare_seq(msa[j-1,:], msa[j,:]) for j in 2:length(msa[:,1])]
        
end


function mut_effect_WTtoB_one_seq(h::Array{Float64,2}, J::Array{Float64,4}, 
        seq, mut_s, b)
    
    seq_pre = deepcopy(seq)
    seq_post = deepcopy(seq)
    
    seq_post[mut_s] = b
    
    return delta_energy(h,J, seq_post, seq_pre)
    
end


function mut_effect_WTtoA_one_seq(h::Array{Float64,2}, J::Array{Float64,4}, 
        seq, mut_s, a)
    
    seq_pre = deepcopy(seq)
    seq_post = deepcopy(seq)
    
    seq_post[mut_s] = a
    
    return delta_energy(h,J, seq_post, seq_pre)
    
end

   
function cont_entr_over_time(h::Array{Float64,2}, J::Array{Float64,4}, 
        seq_chain::Array{Int8,2}, mut_t, mut_s, a, b, window)
    
    res = Array{Float64}(undef,2*window+1)
    idx = 0
    for i in mut_t-window:mut_t
        idx+=1
        
        if seq_chain[i,:] == seq_chain[i-1,:] 
            #println("no mut")
            if idx !=1
                res[idx] = res[idx-1]
            end
        else        
            res[idx] = mut_effect_WTtoB_one_seq(h, J, seq_chain[i,:], mut_s, b)
        end
    end

    for i in mut_t+1:mut_t+window
        idx+=1
        
        if seq_chain[i,:] == seq_chain[i-1,:] 
            #println("no mut")
            if idx !=1
                res[idx] = res[idx-1]
            end
        else        
            res[idx] = mut_effect_WTtoA_one_seq(h, J, seq_chain[i,:], mut_s, a)
        end
    end

    return res
end

function cont_entr_setofmuts(h::Array{Float64,2}, J::Array{Float64,4}, 
        seq_chain::Array{Int8,2}, mut_times::Array{Int64,1}, 
        mut_sites::Array{Int64,1}, a, b, n_muts, start_t,window)
    res = Array{Float64}(undef, n_muts, 2*window+1)
    for i in 1:n_muts
        res[i,:] = cont_entr_over_time(h, J, 
            seq_chain, mut_times[start_t+i], mut_sites[start_t+i], 
            a[start_t+i], b[start_t+i], window)
    end
    return res
end

function cont_entr_setofmuts_eachstep(h::Array{Float64,2}, J::Array{Float64,4}, 
        seq_chain::Array{Int8,2}, mut_times::Array{Int64,1}, 
        mut_sites::Array{Int64,1}, a, b, window, mut_range)
    res = Array{Float64}(undef, length(mut_range), 2*window+1)
    idx = 0
    for i in mut_range
        idx +=1
        res[idx,:] = cont_entr_over_time(h, J, seq_chain, mut_times[i], mut_sites[i], 
            a[i], b[i], window)
    end
    return res
end

function get_entropy(f)
    N=length(f[1,:])
    entr = zeros(Float64, N)
    for i in 1:N
        for a in 1:20
            if(f[a,i]>0)
                entr[i]-=f[a,i]*log(f[a,i])
            end
        end
    end
    
    return entr
end

function cont_dep_entr_without_deg(background, h, J)
    
    T = 1.0
    N = length(background)
    
    prob = hcat([ProbabilityWeights(proba_DNA_gibbs_without_deg(pos_mut, background, h, J, N, T)) for pos_mut in 1:N]...)
    #println(size(prob))
    return get_entropy(prob)[:]
end

function proba_DNA_gibbs_without_deg(k, mutated_seq, h, J,N,  T = 1)
	prob = zeros(20)
	for i in 1:20
        q_k = i
		log_proba = h[q_k, k]
 		for j in 1:N
			log_proba += J[mutated_seq[j], q_k , j, k]
		end
		prob[i] = exp(log_proba/T)
	end
	return normalize(prob,1)
    
end


function cde_1site(site, background, h, J)
    T = 1.0
    N = length(background)
    prob = ProbabilityWeights(proba_DNA_gibbs_without_deg(site, 
            background, h, J, N, T))
    return get_entropy(prob)
end
# Out:
# cde_1site (generic function with 1 method)

# %%
path_wt_pse = "../data/alignments/refs/PSE1_pfam_DNA.fasta"

#load wt
wt_pse = join(readdlm(path_wt_pse, skipstart = 1))
L_pse = Int64(length(wt_pse)/3)
pse_DNA_seq = [wt_pse[((i-1)*3 +1):(i*3)] for i in 1:L_pse]
pse_amino_seq = [cod2amino[codon] for codon in pse_DNA_seq]
path_beta = "../data/alignments/natural/PF13354_noinsert_max19gaps_nodupl_noclose.faa"
nat_beta = Int8.(fasta2matrix(path_beta))
path_nat = "../data/alignments/natural/PF13354_noinsert_max19gaps_nodupl_noclose.faa"
nat_MSA = Int8.(fasta2matrix(path_nat))
path_dbd = "../data/alignments/natural/DBD_alignment.uniref90.cov80.a2m"
nat_dbd = Int8.(fasta2matrix(path_dbd))
;

# %%
folder_path = "../data/chains/equil_det_bal_dbd_silico_chain_num_1_T_1.0.mixedDNA"
#folder_path = "../data_matteo/src/amino_mixed_dbd_steps60000_seqs2_T1.0p0.0/equil_det_bal_dbd_silico_chain_num_1_T_1.0.mixedDNA"

@time matrices = Int8.(fasta2matrix(folder_path))
@time pos = find_positions(matrices)
mut_times = [i for (i, val) in enumerate(pos) if val != 0]
mut_sites = [val for val in pos if val != 0]
;
# Out:
#   0.001861 seconds (7.23 k allocations: 978.594 KiB)
#   0.171908 seconds (276.25 k allocations: 18.236 MiB, 99.61% compilation time)

# %%
CDE_nat = readdlm("../data/figures/suppl_data_fig2/cde_dbd", '\t')
;

# %%
m_cde_nat = mean(CDE_nat, dims = 1)[:]
st_cde_nat = std(CDE_nat, dims = 1)[:]
;

# %%
wt_thornton = Int8.(readdlm("../data/alignments/refs/wt_thornton",'\t'))[:]
;

# %%
L = 76
@time freqs_nat = reshape(compute_weighted_frequencies(Int8.(nat_dbd'), 0.2)[1], (20, L))
entr_nat = get_entropy(freqs_nat)
gap_f = 1 .- [sum(freqs_nat[:,i]) for i in 1:76]
;
# Out:
# θ = 0.2 threshold = 15.0
# M = 24944 N = 76 Meff = 3129.1468140631705
#   5.176254 seconds (300.38 k allocations: 69.462 MiB, 9.88% compilation time)

# %%
freqs_nat_gap = rand(21,76)
freqs_nat_gap[1:20,:] = freqs_nat
freqs_nat_gap[21,:] = gap_f
;

# %%
using DataFrames


a = []
b = []
c = []
d = []
e = []
f = []


for i in 1:length(mut_times)
    push!(a, matrices[mut_times[i], mut_sites[i]])
    push!(b, matrices[mut_times[i]+1, mut_sites[i]])
    push!(c, cde_1site(mut_sites[i], matrices[mut_times[i]], h, J)[1] / log(2))
    push!(d, m_cde_nat[mut_sites[i]] /log(2))
    push!(e, st_cde_nat[mut_sites[i]] /log(2))
    push!(f, entr_nat[mut_sites[i]] /log(2))
    
end
 
# Create a DataFrame from the lists
data = DataFrame(site_i = mut_sites, amino_a = a, amino_b = b, time = mut_times,
    cde_local = c, cde_global = d, st_cde_global = e, cie = f)
;

# %%
data
# Out:
# 1200×8 DataFrame
#   Row │ site_i  amino_a  amino_b  time   cde_local  cde_global  st_cde_global  ⋯
#       │ Int64   Any      Any      Int64  Any        Any         Any            ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │     23  1        6            1  3.14964    1.01169     0.910293       ⋯
#     2 │      9  16       12           2  3.64305    1.69576     0.845723
#     3 │     38  13       15           3  3.8163     2.90429     0.849293
#     4 │      7  15       19           4  3.64284    2.81942     0.68648
#     5 │     33  1        16           5  3.83426    3.02432     0.69887        ⋯
#     6 │      9  12       9            6  3.64305    1.69576     0.845723
#     7 │      9  9        12           7  3.64305    1.69576     0.845723
#     8 │      5  6        1            8  2.24511    1.8388      0.777658
#     9 │     16  10       15           9  3.84154    3.03826     0.669719       ⋯
# ...

# %%
plot(data[:,4], xlabel= "index of mut array", 
    ylabel="time in simulation", xscale =:log10, yscale =:log10)

# %%
start_t = 10000
n_muts = 5000
lag = 3
window = 5000
each_step = start_t:lag:(start_t-1)+(lag*n_muts)
println(length(each_step))
println(each_step)


@time y = cont_entr_setofmuts_eachstep(h, J, matrices, mut_times, 
    mut_sites, data[:,2], data[:,3], window, each_step)
;
# Out:
# 5000
# 10000:3:24997
# BoundsError: attempt to access 1200-element Vector{Int64} at index [10000]
#
# Stacktrace:
#  [1] getindex
#    @ ./essentials.jl:13 [inlined]
#  [2] cont_entr_setofmuts_eachstep(h::Matrix{Float64}, J::Array{Float64, 4}, seq_chain::Matrix{Int8}, mut_times::Vector{Int64}, mut_sites::Vector{Int64}, a::Vector{Any}, b::Vector{Any}, window::Int64, mut_range::StepRange{Int64, Int64})
#    @ Main ./In[3]:95
#  [3] macro expansion
#    @ ./timing.jl:279 [inlined]
#  [4] top-level scope
#    @ ./In[24]:10

# %%
mut_data = data[each_step,:]
using CSV
CSV.write("../suppl_data_fig3/cont_entr_df.csv", mut_data)
;

# %%
x = 2:window-49
cont = y[:, 50:window-1]
entren = y[:, window+2:end-50]
;

# %%
@time writedlm("../suppl_data_fig3/cont", cont)
# Out:
#  44.943776 seconds (49.54 M allocations: 10.338 GiB, 4.89% gc time, 0.43% compilation time)

# %%
@time writedlm("../suppl_data_fig3/entren", entren)
# Out:
#  21.898244 seconds (49.51 M allocations: 10.337 GiB, 9.57% gc time)

# %%
@time writedlm("../suppl_data_fig3/x_steps", x)
# Out:
#   0.178462 seconds (35.85 k allocations: 2.263 MiB, 91.48% compilation time)

# %% [markdown]
# ## new part on fantini data, contingency

# %%
function find_indices_above_threshold(matrix, threshold, exclude_indices)
    indices_above_threshold = [(i, j) for i in 1:size(matrix, 1), j in 1:size(matrix, 2) if matrix[i, j] > threshold]
    filtered_indices = filter(idx -> idx ∉ exclude_indices, indices_above_threshold)
    return filtered_indices
end


function get_exp_cont(f_exp_rounds, wt, wt_idx, tresh, h, J)
    
    mean_res = []
    previous_muts = []
    i = 1
    n_muts = []
    for f in f_exp_rounds
        if i == 1
            muts = find_indices_above_threshold(f, tresh, wt_idx)
            dE = check_exp_muts_in_wt(muts, wt, h, J)
            push!(mean_res, mean(dE))
            previous_muts = muts
            i += 1
            push!(n_muts, length(muts))
        else
            muts = find_indices_above_threshold(f, tresh, 
                vcat(wt_idx, previous_muts))
            dE = check_exp_muts_in_wt(muts, wt, h, J)
            push!(mean_res, mean(dE))
            previous_muts = muts
            i += 1
            push!(n_muts, length(muts))
        end
    end
    println("Selecting muts with f > $(tresh)")
    print("Number of muts ")
    println(n_muts[:])
    return mean_res
end

function get_exp_cont_with_std(f_exp_rounds, wt, wt_idx, tresh, h, J)
    
    mean_res = []
    std_res = []
    previous_muts = []
    i = 1
    n_muts = []
    for f in f_exp_rounds
        if i == 1
            muts = find_indices_above_threshold(f, tresh, wt_idx)
            dE = check_exp_muts_in_wt(muts, wt, h, J)
            push!(mean_res, mean(dE))
            push!(std_res, std(dE))
            previous_muts = muts
            i += 1
            push!(n_muts, length(muts))
        else
            muts = find_indices_above_threshold(f, tresh, 
                vcat(wt_idx, previous_muts))
            dE = check_exp_muts_in_wt(muts, wt, h, J)
            push!(mean_res, mean(dE))
            push!(std_res, std(dE))
            previous_muts = muts
            i += 1
            push!(n_muts, length(muts))
        end
    end
    return mean_res, std_res
end
# Out:
# get_exp_cont_with_std (generic function with 1 method)

# %%
function find_common_muts(lists::Vector{Vector{T}}) where T
    if isempty(lists)
        throw(ArgumentError("At least one list must be provided"))
    end
    
    if any(isempty, lists)
        return Int[]
    end
    
    matching_indices = Set(1:length(lists[1]))
    
    for lst in lists[2:end]
        matching_indices = intersect(matching_indices, findall(t -> t in lst, lists[1]))
    end
    
    return collect(matching_indices)
end

function number_of_seqs(z, f_exp, tresh, wt_idx)
    res = []
    for t in tresh

        mut_lists = [find_indices_above_threshold(f, t, wt_idx) 
            for f in f_exp]
        muts_idx = find_common_muts(mut_lists)
        common_muts = mut_lists[1][muts_idx]
        m = []
    
    
        for mut in common_muts 
            for msa in z
                push!(m, sum(msa[mut[2],:] .== mut[1]))
            end
        end
        println(m)
        println((t, minimum(m)))
        push!(res, minimum(m))
    end
    return res
end

function sample_exp_seqs(mut, msa, n_exp_seqs)
    available_seqs = msa[:, msa[mut[2],:] .== mut[1]]
    #println(n_exp_seqs) 
    #println(size(available_seqs, 2))
    if n_exp_seqs > size(available_seqs, 2)
        println("Please compute the mean of deltaE on fewer \n
            experimental sequences, there are not that many available \n
            for the selected mutation")
    end
    col_idx = sample(1:size(available_seqs, 2), n_exp_seqs, replace = false)
    return available_seqs[:, col_idx]
end

function check_1_wt_amino_in_exp_seqs(msa, mut, wt, h, J)
    dEs = zeros(size(msa,2))
    for l in 1:size(msa,2)
        old_seq = deepcopy(msa[:,l])
        new_seq = deepcopy(msa[:,l])
        new_seq[mut[2]] = wt[mut[2]] 
        dEs[l] = delta_energy(h, J, new_seq, old_seq)
    end
    return mean(dEs), std(dEs)
end

function give_exp_entren(f_exp_rounds, z, n_seqs, wt,
        tresh, h, J)
    
    mut_lists = [find_indices_above_threshold(f, tresh, wt_idx) 
            for f in f_exp_rounds]

    
    #println(typeof(mut_lists))
    muts_idx = find_common_muts(mut_lists)
    common_muts = mut_lists[1][muts_idx]
    
    if length(common_muts) .== 0
        println("lower the thresh, no common muts found in exp rounds")
    else
        print("Number of common muts at treshold $(tresh) ")
        println(length(common_muts))
    end
    
    mean_muts =[]
    st_muts = []
    
    for round in z
        
        m_all = []
        st_all = []
        for mut in common_muts
            sub_round = sample_exp_seqs(mut, round, n_seqs)
            m, st = check_1_wt_amino_in_exp_seqs(sub_round, mut, wt, h, J)
            push!(m_all, m)
            push!(st_all, st)
            m_tot = mean(m_all)
            st_tot = (st_all .^2)./(sqrt(length(st_all)))
        end
        m_tot = mean(m_all)
        st_tot = sum(st_all .^2)./(sqrt(length(st_all)))
        push!(mean_muts, m_tot)
        push!(st_muts, st_tot)
    end
    
    #println(st_muts)
    
    return mean_muts
end
            
   
function give_exp_entren_with_std(f_exp_rounds, z, n_seqs, wt,
        tresh, h, J)
    
    mut_lists = [find_indices_above_threshold(f, tresh, wt_idx) 
            for f in f_exp_rounds]

    
    #println(typeof(mut_lists))
    muts_idx = find_common_muts(mut_lists)
    common_muts = mut_lists[1][muts_idx]
    
    if length(common_muts) .== 0
        println("lower the thresh, no common muts found in exp rounds")
    else
        print("Number of common muts at treshold $(tresh) ")
        println(length(common_muts))
    end
    
    mean_muts =[]
    st_muts = []
    
    for round in z
        
        m_all = []
        st_all = []
        for mut in common_muts
            sub_round = sample_exp_seqs(mut, round, n_seqs)
            m, st = check_1_wt_amino_in_exp_seqs(sub_round, mut, wt, h, J)
            push!(m_all, m)
            push!(st_all, st)
            m_tot = mean(m_all)
            st_tot = (st_all .^2)./(sqrt(length(st_all)))
        end
        m_tot = mean(m_all)
        st_tot = sum(st_all .^2)./(sqrt(length(st_all)))
        push!(mean_muts, m_tot)
        push!(st_muts, st_tot)
    end
    
    
    return mean_muts, st_muts
end
# Out:
# give_exp_entren_with_std (generic function with 1 method)

# %%
path_wt_tem = "alignments/refs/wt_DNA/TEM1_pfam_DNA.fasta"

#load wt
wt_tem = join(readdlm(path_wt_tem, skipstart = 1))
L_tem = Int64(length(wt_tem)/3)
tem_DNA_seq = [wt_tem[((i-1)*3 +1):(i*3)] for i in 1:L_tem]
tem_amino_seq = [cod2amino[codon] for codon in tem_DNA_seq]

path_wt_pse = "../data_matteo/alignments/refs/wt_DNA/PSE1_pfam_DNA.fasta"

#load wt
wt_pse = join(readdlm(path_wt_pse, skipstart = 1))
L_pse = Int64(length(wt_pse)/3)
pse_DNA_seq = [wt_pse[((i-1)*3 +1):(i*3)] for i in 1:L_pse]
pse_amino_seq = [cod2amino[codon] for codon in pse_DNA_seq]

path_wt_aac = "../data_matteo/alignments/refs/wt_DNA/AAC6_pfam_DNA.fasta"

#load wt
wt_aac = join(readdlm(path_wt_aac, skipstart = 1))
L_aac = Int64(length(wt_aac)/3)
aac_DNA_seq = [wt_aac[((i-1)*3 +1):(i*3)] for i in 1:L_aac]
aac_amino_seq = [cod2amino[codon] for codon in aac_DNA_seq]
;

# %%
h_tem = h
J_tem = J
h_pse = h
J_pse = J
;

# %%
function compute_single_ddE_cont(h::Array{Float64,2}, J::Array{Float64,4}, 
        wt::Array{Int8, 1}, seq::Array{Int8, 1}, site::Int64)
    new_wt = deepcopy(wt)
    new_seq = deepcopy(seq)
    new_wt[site] = seq[site]
    new_seq[site] = wt[site]
    return delta_energy(h, J, new_wt, wt) .+ delta_energy(h, J, new_seq, seq)
end

function compute_ddE_cont!(dde, h::Array{Float64,2}, J::Array{Float64,4}, 
        wt::Array{Int8, 1}, seq::Array{Int8, 1}, filt::Array{Tuple{Int64, Int64}, 1})
    
    mut_site = findall(x -> x == 1, wt .!= seq)
    aa_seq = seq[mut_site]
    
    if length(mut_site) == 0
        #println("no muts between the sequences")
    else
        muts = [(aa_seq[i], mut_site[i]) for i in 1:length(aa_seq)]
        filt_muts = filter(t -> t in muts, filt)
        d = Int(KitMSA.my_hamming(wt, seq))
        push!(dde[d], [compute_single_ddE_cont(h, J, wt, seq, mut[2]) 
            for mut in filt_muts]...)
        #println(d)
    end
end

function get_exp_cont2(max_ham, f_exp_rounds, z, wt, wt_idx, tresh, h, J)
    
    mean_res = []
    previous_muts = []
    i = 1
    dde = Vector{Vector{Float64}}(undef, 100)
    for i in 1:100
        dde[i] = Vector{Float64}[]
    end

    for f in f_exp_rounds
        if i == 1
            println("round $i")
            muts = find_indices_above_threshold(f, tresh, wt_idx)
            for n in 1:size(z[i])[2]
                compute_ddE_cont!(dde, h, J, wt, z[i][:,n], muts)
            end
            println((i, length(muts)))
            #push!(previous_muts, muts...)
            i+=1
            println(length(previous_muts))
        else
            println("round $i")
            muts = find_indices_above_threshold(f, tresh, 
                vcat(wt_idx, previous_muts))
            for n in 1:size(z[i])[2]
                compute_ddE_cont!(dde, h, J, wt, z[i][:,n], muts)
            end
            println((i, length(muts)))
            #push!(previous_muts, muts...)
            i+=1
            println(length(previous_muts))
        end
    end
    return dde[1:max_ham]
end
# Out:
# get_exp_cont2 (generic function with 2 methods)

# %% [markdown]
# ## TEM

# %%
wt = tem_amino_seq
file_tem1 = "../data_matteo/alignments/experimental/TEM/fantini.max.6.gaps.gen1.fa"
file_tem5 = "../data_matteo/alignments/experimental/TEM/fantini.max.6.gaps.gen5.fa"
file_tem12 = "../data_matteo/alignments/experimental/TEM/fantini.max.6.gaps.gen12.fa"
z_tem = [Int8.(fasta2matrix(file_tem1)'), Int8.(fasta2matrix(file_tem5)'),
        Int8.(fasta2matrix(file_tem12)')]
L = length(wt)
;

# %%
subsample = 10000
z_sub_tem = [z[:,rand(1:length(z[1,:]), subsample)] for z in z_tem]
f_tem = [reshape(compute_weighted_frequencies(z, 0.)[1], (20, L)) 
    for z in z_sub_tem]
wt_idx_tem = [(wt[i],i) for i in 1:length(wt)]
d_tem = [mean(count_muts_msa(msa', wt)) for msa in z_tem]
;
# Out:
# θ = 0.0 threshold = 0.0
# M = 10000 N = 202 Meff = 10000
# θ = 0.0 threshold = 0.0
# M = 10000 N = 202 Meff = 10000
# θ = 0.0 threshold = 0.0
# M = 10000 N = 202 Meff = 10000

# %%
wt = tem_amino_seq
folder_path = "../data_matteo/src/new_fixed_amino_mixed_tem_steps200_seqs10000_T1.14p0.0/"
fasta_files = filter(file -> endswith(file, ".mixedDNA"), readdir(folder_path))
@time matrices = [Int8.(fasta2matrix(joinpath(folder_path, file))) 
    for file in fasta_files]
l = [length(matrices[i][:,1]) for i in 1:length(matrices)]
good_matr = matrices[l .> 19]
g_matr = [good_matr[i][1:20,:] for i in 1:length(good_matr)]
idx = [2*i for i in 1:10]
z_tem_sil = build_seq_matrices(g_matr)[idx]
;
# Out:
# get_exp_cont2 (generic function with 2 methods)

# %%
L = length(wt)
wt_idx_tem = [(wt[i],i) for i in 1:length(wt)]
@time f_tem_sil = [reshape(compute_weighted_frequencies(Int8.(z'), 0.)[1], (20, L)) 
    for z in z_tem_sil]
;

# %%
tresh = 0.0
max_ham = 17
@time dde_C_TEM = get_exp_cont2(max_ham, f_tem, z_sub_tem, 
    wt, wt_idx_tem, tresh, h, J)
@time dde_C_TEM_sil = get_exp_cont2(max_ham, f_tem_sil, [Int8.(z') 
        for z in z_tem_sil], wt, wt_idx_tem, tresh, h, J)
;
# Out:
# round 1
# (1, 1254)
# 0
# round 2
# (2, 1478)
# 0
# round 3
# (3, 1561)
# 0
#   9.777164 seconds (6.91 M allocations: 3.167 GiB, 8.79% gc time, 11.91% compilation time)

# %%
m_C_TEM = [mean(a) for a in dde_C_TEM]
s_C_TEM = [std(a) for a in dde_C_TEM]
m_C_TEM_sil = [mean(a) for a in dde_C_TEM_sil]
s_C_TEM_sil= [std(a) for a in dde_C_TEM_sil]
x = 1:max_ham
L = 202/100
x_sil = [2*i+1 for i in 0:8]
;

# %%
scatter(x ./L, .-m_C_TEM, yerr = s_C_TEM, title = "Contingency",
    xlabel = "Sequence divergence (%)", ylabel = "ΔΔF", label = "TEM")
plot!(x_sil ./L, .-m_C_TEM_sil[x_sil], ribbon = s_C_TEM_sil[x_sil],
    label = "TEM silico")
savefig("../beta_tem_contingency_tot.png")
# Out:
# "/home/leonardo/Documents/beta_tem_contingency_tot.png"

# %% [markdown]
# ## PSE

# %%
wt = pse_amino_seq
file_pse10 = "../data_matteo/alignments/experimental/PSE/PSE-1_Round10_masked.fa"
file_pse20 = "../data_matteo/alignments/experimental/PSE/PSE1_Round20_pfam.fasta"
z_pse = [Int8.(fasta2matrix(file_pse10)'), Int8.(fasta2matrix(file_pse20)')]
L = length(wt)
;

# %%
subsample = 10000
z_sub_pse = [z[:,rand(1:length(z[1,:]), subsample)] for z in z_pse]
@time f_pse = [reshape(compute_weighted_frequencies(z, 0.)[1], (20, L)) 
    for z in z_sub_pse]
wt_idx_pse = [(wt[i],i) for i in 1:length(wt)]
d_pse = [mean(count_muts_msa(msa', wt)) for msa in z_pse]
;
# Out:
# θ = 0.0 threshold = 0.0
# M = 10000 N = 202 Meff = 10000
# θ = 0.0 threshold = 0.0
# M = 10000 N = 202 Meff = 10000
#   3.890500 seconds (104.15 k allocations: 638.093 MiB, 2.12% gc time, 2.97% compilation time)

# %%
wt = pse_amino_seq
folder_path = "../data_matteo/src/new_fixed_amino_mixed_pse_steps250_seqs10000_T1.33p0.0/"
fasta_files = filter(file -> endswith(file, ".mixedDNA"), readdir(folder_path))
@time matrices = [Int8.(fasta2matrix(joinpath(folder_path, file))) 
    for file in fasta_files]
l = [length(matrices[i][:,1]) for i in 1:length(matrices)]
good_matr = matrices[l .> 29]
g_matr = [good_matr[i][1:30,:] for i in 1:length(good_matr)]
idx = [3*i for i in 1:10]
z_pse_sil = build_seq_matrices(g_matr)[idx]
;
# Out:
#  16.978505 seconds (2.63 M allocations: 676.298 MiB, 0.86% gc time, 1.03% compilation time)

# %%
wt_idx_pse = [(wt[i],i) for i in 1:length(wt)]
d_pse_sil = [mean(count_muts_msa(msa, wt)) for msa in z_pse_sil]
;

# %%
@time f_pse_sil = [reshape(compute_weighted_frequencies(Int8.(z'), 0.)[1], (20, L)) 
    for z in z_pse_sil]
;
# Out:
# θ = 0.0 threshold = 0.0
# M = 9971 N = 202 Meff = 9971
# θ = 0.0 threshold = 0.0
# M = 9971 N = 202 Meff = 9971
# θ = 0.0 threshold = 0.0
# M = 9971 N = 202 Meff = 9971
# θ = 0.0 threshold = 0.0
# M = 9971 N = 202 Meff = 9971
# θ = 0.0 threshold = 0.0
# M = 9971 N = 202 Meff = 9971
# θ = 0.0 threshold = 0.0
# M = 9971 N = 202 Meff = 9971
# θ = 0.0 threshold = 0.0
# M = 9971 N = 202 Meff = 9971
# θ = 0.0 threshold = 0.0
# M = 9971 N = 202 Meff = 9971
# θ = 0.0 threshold = 0.0
# M = 9971 N = 202 Meff = 9971
# θ = 0.0 threshold = 0.0
# M = 9971 N = 202 Meff = 9971
#  19.431688 seconds (407.40 k allocations: 3.127 GiB, 3.02% gc time, 1.03% compilation time)

# %%
tresh = 0.0
max_ham = 27
@time dde_C_PSE = get_exp_cont2(max_ham, f_pse, z_sub_pse, 
    wt, wt_idx_pse, tresh, h, J)
@time dde_C_PSE_sil = get_exp_cont2(max_ham, f_pse_sil, [Int8.(z') 
        for z in z_pse_sil], wt, wt_idx_pse, tresh, h, J)
;
# Out:
# round 1
# (1, 1749)
# 0
# round 2
# (2, 2067)
# 0
#  13.604145 seconds (9.02 M allocations: 4.421 GiB, 7.22% gc time)
# round 1
# (1, 1296)
# 0
# round 2
# (2, 1711)
# 0
# round 3
# (3, 2047)
# 0
# round 4
# (4, 2304)
# 0
# round 5
# (5, 2509)
# 0
# round 6
# (6, 2700)
# 0
# round 7
# (7, 2828)
# 0
# round 8
# (8, 2946)
# 0
# round 9
# (9, 3042)
# 0
# round 10
# (10, 3130)
# 0
#  51.233490 seconds (35.71 M allocations: 17.409 GiB, 7.48% gc time, 0.26% compilation time)

# %%
m_C_PSE = [mean(a) for a in dde_C_PSE]
s_C_PSE = [std(a) for a in dde_C_PSE]
m_C_PSE_sil = [mean(a) for a in dde_C_PSE_sil]
s_C_PSE_sil= [std(a) for a in dde_C_PSE_sil]
x = 1:max_ham
L = 202/100
x_sil = [2,5,8,11,14,17,20,23,26]

;

# %%
scatter(x ./L, .-m_C_PSE, yerr = s_C_PSE, title = "Contingency",
    xlabel = "Sequence divergence (%)", ylabel = "ΔΔF", label = "PSE")
plot!(x_sil ./L, .-m_C_PSE_sil[x_sil], ribbon = s_C_PSE_sil[x_sil],
    label = "PSE silico")
savefig("../beta_pse_contingency_tot.png")
# Out:
# "/home/leonardo/Documents/beta_pse_contingency_tot.png"

# %% [markdown]
# ## AAC

# %%
wt = aac_amino_seq
file_aac2 = "../data_matteo/alignments/experimental/AAC/AAC6_A2_pfam117.fasta"
file_aac4 = "../data_matteo/alignments/experimental/AAC/AAC6_A4_pfam117.fasta"
file_aac8 = "../data_matteo/alignments/experimental/AAC/AAC6_A8_pfam117.fasta"
z_aac = [Int8.(fasta2matrix(file_aac2)'), Int8.(fasta2matrix(file_aac4)'),
        Int8.(fasta2matrix(file_aac8)')]
L = length(wt)
f_aac = [reshape(compute_weighted_frequencies(z, 0.)[1], (20, L)) for z in z_aac]
wt_idx_aac = [(wt[i],i) for i in 1:length(wt)]
d_aac = [mean(count_muts_msa(msa', wt)) for msa in z_aac]
;
# Out:
# θ = 0.0 threshold = 0.0
# M = 135330 N = 117 Meff = 135330
# θ = 0.0 threshold = 0.0
# M = 182960 N = 117 Meff = 182960
# θ = 0.0 threshold = 0.0
# M = 1260048 N = 117 Meff = 1260048

# %%
wt = aac_amino_seq
tresh = 0.005:0.005:0.05
@time m_C_AAC = hcat([get_exp_cont(f_aac, wt, wt_idx_aac, t, h_aac, J_aac) 
        for t in tresh]...)
;
# Out:
# Selecting muts with f > 0.005
# Number of muts Any[216, 25, 248]
# Selecting muts with f > 0.01
# Number of muts Any[119, 51, 143]
# Selecting muts with f > 0.015
# Number of muts Any[77, 42, 109]
# Selecting muts with f > 0.02
# Number of muts Any[45, 48, 80]
# Selecting muts with f > 0.025
# Number of muts Any[24, 43, 65]
# Selecting muts with f > 0.03
# Number of muts Any[8, 42, 49]
# Selecting muts with f > 0.035
# Number of muts Any[3, 29, 52]
# Selecting muts with f > 0.04
# Number of muts Any[1, 22, 43]
# Selecting muts with f > 0.045
# Number of muts Any[1, 12, 43]
# Selecting muts with f > 0.05
# Number of muts Any[0, 9, 37]
#   3.048205 seconds (509.09 k allocations: 21.133 MiB)

# %%
tresh = 0.005:0.005:0.05
# Out:
# 0.005:0.005:0.05

# %%
p = plot()
for i in 1:10
    t = tresh[i]
    plot!(p, d_aac, m_C_AAC[:,i], label =" $(t)")
end
display(p)

# %%
tresh = 0.03
wt = aac_amino_seq
m_C_AAC, st_C_AAC = get_exp_cont_with_std(f_aac, wt, wt_idx_aac, 
    tresh, h_aac, J_aac)
scatter(d_aac, m_C_AAC, yerr = st_C_AAC)

# %%
tresh = 0.005:0.005:0.05
n_aac = number_of_seqs(z_aac, f_aac, tresh, wt_idx_aac)
;
# Out:
# (0.005, 680)
# (0.01, 1368)
# (0.015, 2061)
# (0.02, 2709)
# (0.025, 3489)
# (0.03, 4263)
# (0.035, 4818)
# (0.04, 6160)
# (0.045, 6160)
# MethodError: reducing over an empty collection is not allowed; consider supplying `init` to the reducer
#
# Stacktrace:
#   [1] mapreduce_empty(#unused#::typeof(identity), op::Function, T::Type)
#     @ Base ./reduce.jl:367
#   [2] reduce_empty(op::Base.MappingRF{typeof(identity), typeof(min)}, #unused#::Type{Any})
#     @ Base ./reduce.jl:356
#   [3] reduce_empty_iter
#     @ ./reduce.jl:379 [inlined]
#   [4] mapreduce_empty_iter(f::Function, op::Function, itr::Vector{Any}, ItrEltype::Base.HasEltype)
#     @ Base ./reduce.jl:375
#   [5] _mapreduce(f::typeof(identity), op::typeof(min), #unused#::IndexLinear, A::Vector{Any})
#     @ Base ./reduce.jl:427
#   [6] _mapreduce_dim
#     @ ./reducedim.jl:365 [inlined]
#   [7] #mapreduce#800
#     @ ./reducedim.jl:357 [inlined]
#   [8] mapreduce
#     @ ./reducedim.jl:357 [inlined]
#   [9] #_minimum#822
# ...

# %%
tresh = 0.005:0.005:0.05
n_aac = 100
wt = aac_amino_seq
@time m_E_AAC  = hcat([give_exp_entren(f_aac, z_aac, n_seqs, wt,
        t, h_aac, J_aac) for t in tresh]...)
;
# Out:
# Number of common muts at treshold 0.005 298
# Number of common muts at treshold 0.01 209
# Number of common muts at treshold 0.015 171
# Number of common muts at treshold 0.02 146
# Number of common muts at treshold 0.025 129
# Number of common muts at treshold 0.03 114
# Number of common muts at treshold 0.035 109
# Number of common muts at treshold 0.04 107
# Number of common muts at treshold 0.045 107
# Number of common muts at treshold 0.05 106
# 701.161897 seconds (34.67 M allocations: 183.449 GiB, 4.09% gc time)

# %%
plot(d_aac, m_E_AAC)

# %%
tresh = 0.03
n_seqs = 500
wt = aac_amino_seq
@time single_m_E_AAC, st_E_AAC = give_exp_entren_with_std(f_aac, z_aac, n_seqs, wt,
        tresh, h_aac, J_aac)
scatter(d_aac, single_m_E_AAC, yerr = st_E_AAC)
# Out:
# Number of common muts at treshold 0.03 114
#  68.956797 seconds (2.60 M allocations: 17.879 GiB, 3.66% gc time)

# %%
### scatter frequency of mutations versus effect of mutation in the context

# %%
#check_exp_muts_in_wt(mut_list, wt, h, J)
